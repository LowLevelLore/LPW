# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
import numpy as np
import copy

# %%
class SampleNet(nn.Module):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.input_layer = nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3) # 28*28*1 -> 26*26*4
        self.pooling = nn.MaxPool2d(kernel_size=2) 
        self.activation = nn.ReLU()
        self.conv = nn.Conv2d(in_channels=4, out_channels=16, kernel_size=3)
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(in_features=11*11*16, out_features=512)
        self.dropout = nn.Dropout(0.2)
        self.output = nn.Linear(in_features=512, out_features=10)
    
    def forward(self, x):
        x = self.pooling(self.activation(self.input_layer(x))) # 28 * 28 * 1 -> 26 * 26 * 4 -> 13 * 13 * 4
        x = self.activation(self.conv(x)) # 13 * 13 * 4 -> 11 * 11 * 16
        return self.output(self.dropout(self.linear(self.flatten(x)))) # 11 * 11 * 16 -> 512 -> 10

# %%
def evaluate_model(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            pred = output.argmax(dim=1)
            correct += (pred == target).sum().item()
            total += target.size(0)
    accuracy = 100 * correct / total
    return accuracy

def client_update(model, data, target, lr=0.01):
    model = copy.deepcopy(model)
    model.train()
    
    optimizer = optim.SGD(model.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()
    
    optimizer.zero_grad()
    output = model(data)
    loss = loss_fn(output, target)
    loss.backward()
    optimizer.step()

    return model.state_dict()

# %%
def average_weights(w_list):
    avg_w = copy.deepcopy(w_list[0])
    for key in avg_w.keys():
        for i in range(1, len(w_list)):
            avg_w[key] += w_list[i][key]
        avg_w[key] = torch.div(avg_w[key], len(w_list))
    return avg_w

# %%
global_model = SampleNet()
num_rounds = 500
num_clients = 3

# %%
transform = transforms.ToTensor()
mnist_data = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_data = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

client_data_indices = np.array_split(np.arange(len(mnist_data)), 3)
client_loaders = [DataLoader(Subset(mnist_data, idx), batch_size=32, shuffle=True) for idx in client_data_indices]
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %%
for round in range(num_rounds):
    print(f"\n--- Round {round+1} ---")
    local_weights = []

    for idx in range(num_clients):
        client = iter(client_loaders[idx])
        try:
            data, target = next(client)
        except StopIteration:
            continue
        
        # print(f"Client: {idx + 1}, Target: {target}")
        updated = client_update(global_model, data, target)
        local_weights.append(updated)
        
    if local_weights:
        global_weights = average_weights(local_weights)
        global_model.load_state_dict(global_weights)
    
    acc = evaluate_model(global_model, test_loader)
    print(f"Global Test Accuracy: {acc:.2f}%")
# Out:
# --- Round 1 ---
# Global Test Accuracy: 12.50%
#
# --- Round 2 ---
# Global Test Accuracy: 12.30%
#
# --- Round 3 ---
# Global Test Accuracy: 12.35%
#
# --- Round 4 ---
# Global Test Accuracy: 13.97%
#
# --- Round 5 ---
# Global Test Accuracy: 14.96%
#
# --- Round 6 ---
# Global Test Accuracy: 14.53%
#
# --- Round 7 ---
# Global Test Accuracy: 13.98%
#
# --- Round 8 ---
# Global Test Accuracy: 13.25%
#
# --- Round 9 ---
# Global Test Accuracy: 14.09%
#
# --- Round 10 ---
# Global Test Accuracy: 13.96%
#
# --- Round 11 ---
# Global Test Accuracy: 14.72%
#
# --- Round 12 ---
# Global Test Accuracy: 14.89%
#
# --- Round 13 ---
# Global Test Accuracy: 15.59%
#
# --- Round 14 ---
# Global Test Accuracy: 15.65%
#
# --- Round 15 ---
# Global Test Accuracy: 16.02%
#
# --- Round 16 ---
# Global Test Accuracy: 16.15%
#
# --- Round 17 ---
# Global Test Accuracy: 16.99%
#
# --- Round 18 ---
# Global Test Accuracy: 16.29%
#
# --- Round 19 ---
# Global Test Accuracy: 16.43%
#
# --- Round 20 ---
# Global Test Accuracy: 14.01%
#
# --- Round 21 ---
# Global Test Accuracy: 13.90%
#
# --- Round 22 ---
# Global Test Accuracy: 13.93%
#
# --- Round 23 ---
# Global Test Accuracy: 15.13%
#
# --- Round 24 ---
# Global Test Accuracy: 14.47%
#
# --- Round 25 ---
# Global Test Accuracy: 14.61%
#
# --- Round 26 ---
# Global Test Accuracy: 13.71%
#
# --- Round 27 ---
# Global Test Accuracy: 15.02%
#
# --- Round 28 ---
# Global Test Accuracy: 17.02%
#
# --- Round 29 ---
# Global Test Accuracy: 16.96%
#
# --- Round 30 ---
# Global Test Accuracy: 17.57%
#
# --- Round 31 ---
# Global Test Accuracy: 18.54%
#
# --- Round 32 ---
# Global Test Accuracy: 19.77%
#
# --- Round 33 ---
# Global Test Accuracy: 19.79%
#
# --- Round 34 ---
# Global Test Accuracy: 20.26%
#
# --- Round 35 ---
# Global Test Accuracy: 19.21%
#
# --- Round 36 ---
# Global Test Accuracy: 19.47%
#
# --- Round 37 ---
# Global Test Accuracy: 18.89%
#
# --- Round 38 ---
# Global Test Accuracy: 19.14%
#
# --- Round 39 ---
# Global Test Accuracy: 17.35%
#
# --- Round 40 ---
# Global Test Accuracy: 18.07%
#
# --- Round 41 ---
# Global Test Accuracy: 17.16%
#
# --- Round 42 ---
# Global Test Accuracy: 14.48%
#
# --- Round 43 ---
# Global Test Accuracy: 14.49%
#
# --- Round 44 ---
# Global Test Accuracy: 14.75%
#
# --- Round 45 ---
# Global Test Accuracy: 15.86%
#
# --- Round 46 ---
# Global Test Accuracy: 15.98%
#
# --- Round 47 ---
# Global Test Accuracy: 15.33%
#
# --- Round 48 ---
# Global Test Accuracy: 16.09%
#
# --- Round 49 ---
# Global Test Accuracy: 17.33%
#
# --- Round 50 ---
# Global Test Accuracy: 16.32%
#
# --- Round 51 ---
# Global Test Accuracy: 18.56%
#
# --- Round 52 ---
# Global Test Accuracy: 19.35%
#
# --- Round 53 ---
# Global Test Accuracy: 21.58%
#
# --- Round 54 ---
# Global Test Accuracy: 21.67%
#
# --- Round 55 ---
# Global Test Accuracy: 21.50%
#
# --- Round 56 ---
# Global Test Accuracy: 20.73%
#
# --- Round 57 ---
# Global Test Accuracy: 18.41%
#
# --- Round 58 ---
# Global Test Accuracy: 20.81%
#
# --- Round 59 ---
# Global Test Accuracy: 18.64%
#
# --- Round 60 ---
# Global Test Accuracy: 20.65%
#
# --- Round 61 ---
# Global Test Accuracy: 21.12%
#
# --- Round 62 ---
# Global Test Accuracy: 20.44%
#
# --- Round 63 ---
# Global Test Accuracy: 21.40%
#
# --- Round 64 ---
# Global Test Accuracy: 21.60%
#
# --- Round 65 ---
# Global Test Accuracy: 23.27%
#
# --- Round 66 ---
# Global Test Accuracy: 23.34%
#
# --- Round 67 ---
# Global Test Accuracy: 24.29%
#
# --- Round 68 ---
# Global Test Accuracy: 25.74%
#
# --- Round 69 ---
# Global Test Accuracy: 26.45%
#
# --- Round 70 ---
# Global Test Accuracy: 26.23%
#
# --- Round 71 ---
# Global Test Accuracy: 27.42%
#
# --- Round 72 ---
# Global Test Accuracy: 28.21%
#
# --- Round 73 ---
# Global Test Accuracy: 28.15%
#
# --- Round 74 ---
# Global Test Accuracy: 26.01%
#
# --- Round 75 ---
# Global Test Accuracy: 27.42%
#
# --- Round 76 ---
# Global Test Accuracy: 27.74%
#
# --- Round 77 ---
# Global Test Accuracy: 26.06%
#
# --- Round 78 ---
# Global Test Accuracy: 26.66%
#
# --- Round 79 ---
# Global Test Accuracy: 28.76%
#
# --- Round 80 ---
# Global Test Accuracy: 28.43%
#
# --- Round 81 ---
# Global Test Accuracy: 25.29%
#
# --- Round 82 ---
# Global Test Accuracy: 23.48%
#
# --- Round 83 ---
# Global Test Accuracy: 22.74%
#
# --- Round 84 ---
# Global Test Accuracy: 23.18%
#
# --- Round 85 ---
# Global Test Accuracy: 22.61%
#
# --- Round 86 ---
# Global Test Accuracy: 25.74%
#
# --- Round 87 ---
# Global Test Accuracy: 29.28%
#
# --- Round 88 ---
# Global Test Accuracy: 23.95%
#
# --- Round 89 ---
# Global Test Accuracy: 25.13%
#
# --- Round 90 ---
# Global Test Accuracy: 23.31%
#
# --- Round 91 ---
# Global Test Accuracy: 25.66%
#
# --- Round 92 ---
# Global Test Accuracy: 26.04%
#
# --- Round 93 ---
# Global Test Accuracy: 26.11%
#
# --- Round 94 ---
# Global Test Accuracy: 27.67%
#
# --- Round 95 ---
# Global Test Accuracy: 26.35%
#
# --- Round 96 ---
# Global Test Accuracy: 25.57%
#
# --- Round 97 ---
# Global Test Accuracy: 25.12%
#
# --- Round 98 ---
# Global Test Accuracy: 26.43%
#
# --- Round 99 ---
# Global Test Accuracy: 28.06%
#
# --- Round 100 ---
# Global Test Accuracy: 29.12%
#
# --- Round 101 ---
# Global Test Accuracy: 31.64%
#
# --- Round 102 ---
# Global Test Accuracy: 36.48%
#
# --- Round 103 ---
# Global Test Accuracy: 35.74%
#
# --- Round 104 ---
# Global Test Accuracy: 39.16%
#
# --- Round 105 ---
# Global Test Accuracy: 37.41%
#
# --- Round 106 ---
# Global Test Accuracy: 41.14%
#
# --- Round 107 ---
# Global Test Accuracy: 43.89%
#
# --- Round 108 ---
# Global Test Accuracy: 46.03%
#
# --- Round 109 ---
# Global Test Accuracy: 47.44%
#
# --- Round 110 ---
# Global Test Accuracy: 48.73%
#
# --- Round 111 ---
# Global Test Accuracy: 48.54%
#
# --- Round 112 ---
# Global Test Accuracy: 47.09%
#
# --- Round 113 ---
# Global Test Accuracy: 45.41%
#
# --- Round 114 ---
# Global Test Accuracy: 46.48%
#
# --- Round 115 ---
# Global Test Accuracy: 46.96%
#
# --- Round 116 ---
# Global Test Accuracy: 47.07%
#
# --- Round 117 ---
# Global Test Accuracy: 46.23%
#
# --- Round 118 ---
# Global Test Accuracy: 46.82%
#
# --- Round 119 ---
# Global Test Accuracy: 46.25%
#
# --- Round 120 ---
# Global Test Accuracy: 45.23%
#
# --- Round 121 ---
# Global Test Accuracy: 43.48%
#
# --- Round 122 ---
# Global Test Accuracy: 44.73%
#
# --- Round 123 ---
# Global Test Accuracy: 44.61%
#
# --- Round 124 ---
# Global Test Accuracy: 45.50%
#
# --- Round 125 ---
# Global Test Accuracy: 46.14%
#
# --- Round 126 ---
# Global Test Accuracy: 48.21%
#
# --- Round 127 ---
# Global Test Accuracy: 49.26%
#
# --- Round 128 ---
# Global Test Accuracy: 49.40%
#
# --- Round 129 ---
# Global Test Accuracy: 50.78%
#
# --- Round 130 ---
# Global Test Accuracy: 50.19%
#
# --- Round 131 ---
# Global Test Accuracy: 49.13%
#
# --- Round 132 ---
# Global Test Accuracy: 47.42%
#
# --- Round 133 ---
# Global Test Accuracy: 42.28%
#
# --- Round 134 ---
# Global Test Accuracy: 46.84%
#
# --- Round 135 ---
# Global Test Accuracy: 45.85%
#
# --- Round 136 ---
# Global Test Accuracy: 44.29%
#
# --- Round 137 ---
# Global Test Accuracy: 43.54%
#
# --- Round 138 ---
# Global Test Accuracy: 42.45%
#
# --- Round 139 ---
# Global Test Accuracy: 44.29%
#
# --- Round 140 ---
# Global Test Accuracy: 46.08%
#
# --- Round 141 ---
# Global Test Accuracy: 45.92%
#
# --- Round 142 ---
# Global Test Accuracy: 48.59%
#
# --- Round 143 ---
# Global Test Accuracy: 47.07%
#
# --- Round 144 ---
# Global Test Accuracy: 45.81%
#
# --- Round 145 ---
# Global Test Accuracy: 48.00%
#
# --- Round 146 ---
# Global Test Accuracy: 48.15%
#
# --- Round 147 ---
# Global Test Accuracy: 50.14%
#
# --- Round 148 ---
# Global Test Accuracy: 50.15%
#
# --- Round 149 ---
# Global Test Accuracy: 49.96%
#
# --- Round 150 ---
# Global Test Accuracy: 49.54%
#
# --- Round 151 ---
# Global Test Accuracy: 46.61%
#
# --- Round 152 ---
# Global Test Accuracy: 49.71%
#
# --- Round 153 ---
# Global Test Accuracy: 49.29%
#
# --- Round 154 ---
# Global Test Accuracy: 50.21%
#
# --- Round 155 ---
# Global Test Accuracy: 50.86%
#
# --- Round 156 ---
# Global Test Accuracy: 50.54%
#
# --- Round 157 ---
# Global Test Accuracy: 54.15%
#
# --- Round 158 ---
# Global Test Accuracy: 53.30%
#
# --- Round 159 ---
# Global Test Accuracy: 53.72%
#
# --- Round 160 ---
# Global Test Accuracy: 54.69%
#
# --- Round 161 ---
# Global Test Accuracy: 55.39%
#
# --- Round 162 ---
# Global Test Accuracy: 54.33%
#
# --- Round 163 ---
# Global Test Accuracy: 52.16%
#
# --- Round 164 ---
# Global Test Accuracy: 53.46%
#
# --- Round 165 ---
# Global Test Accuracy: 54.65%
#
# --- Round 166 ---
# Global Test Accuracy: 59.52%
#
# --- Round 167 ---
# Global Test Accuracy: 58.39%
#
# --- Round 168 ---
# Global Test Accuracy: 55.77%
#
# --- Round 169 ---
# Global Test Accuracy: 56.63%
#
# --- Round 170 ---
# Global Test Accuracy: 56.34%
#
# --- Round 171 ---
# Global Test Accuracy: 55.12%
#
# --- Round 172 ---
# Global Test Accuracy: 55.61%
#
# --- Round 173 ---
# Global Test Accuracy: 56.24%
#
# --- Round 174 ---
# Global Test Accuracy: 56.46%
#
# --- Round 175 ---
# Global Test Accuracy: 56.53%
#
# --- Round 176 ---
# Global Test Accuracy: 57.79%
#
# --- Round 177 ---
# Global Test Accuracy: 57.76%
#
# --- Round 178 ---
# Global Test Accuracy: 55.92%
#
# --- Round 179 ---
# Global Test Accuracy: 56.35%
#
# --- Round 180 ---
# Global Test Accuracy: 56.05%
#
# --- Round 181 ---
# Global Test Accuracy: 57.27%
#
# --- Round 182 ---
# Global Test Accuracy: 58.18%
#
# --- Round 183 ---
# Global Test Accuracy: 58.17%
#
# --- Round 184 ---
# Global Test Accuracy: 59.33%
#
# --- Round 185 ---
# Global Test Accuracy: 59.05%
#
# --- Round 186 ---
# Global Test Accuracy: 57.88%
#
# --- Round 187 ---
# Global Test Accuracy: 59.91%
#
# --- Round 188 ---
# Global Test Accuracy: 60.28%
#
# --- Round 189 ---
# Global Test Accuracy: 61.48%
#
# --- Round 190 ---
# Global Test Accuracy: 61.44%
#
# --- Round 191 ---
# Global Test Accuracy: 62.23%
#
# --- Round 192 ---
# Global Test Accuracy: 62.21%
#
# --- Round 193 ---
# Global Test Accuracy: 62.38%
#
# --- Round 194 ---
# Global Test Accuracy: 64.24%
#
# --- Round 195 ---
# Global Test Accuracy: 64.71%
#
# --- Round 196 ---
# Global Test Accuracy: 62.87%
#
# --- Round 197 ---
# Global Test Accuracy: 62.95%
#
# --- Round 198 ---
# Global Test Accuracy: 65.25%
#
# --- Round 199 ---
# Global Test Accuracy: 65.05%
#
# --- Round 200 ---
# Global Test Accuracy: 63.91%
#
# --- Round 201 ---
# Global Test Accuracy: 64.31%
#
# --- Round 202 ---
# Global Test Accuracy: 63.94%
#
# --- Round 203 ---
# Global Test Accuracy: 65.59%
#
# --- Round 204 ---
# Global Test Accuracy: 65.99%
#
# --- Round 205 ---
# Global Test Accuracy: 66.77%
#
# --- Round 206 ---
# Global Test Accuracy: 66.04%
#
# --- Round 207 ---
# Global Test Accuracy: 66.65%
#
# --- Round 208 ---
# Global Test Accuracy: 67.70%
#
# --- Round 209 ---
# Global Test Accuracy: 65.22%
#
# --- Round 210 ---
# Global Test Accuracy: 64.88%
#
# --- Round 211 ---
# Global Test Accuracy: 65.25%
#
# --- Round 212 ---
# Global Test Accuracy: 67.22%
#
# --- Round 213 ---
# Global Test Accuracy: 67.79%
#
# --- Round 214 ---
# Global Test Accuracy: 67.38%
#
# --- Round 215 ---
# Global Test Accuracy: 68.43%
#
# --- Round 216 ---
# Global Test Accuracy: 67.19%
#
# --- Round 217 ---
# Global Test Accuracy: 65.75%
#
# --- Round 218 ---
# Global Test Accuracy: 64.86%
#
# --- Round 219 ---
# Global Test Accuracy: 64.14%
#
# --- Round 220 ---
# Global Test Accuracy: 65.54%
#
# --- Round 221 ---
# Global Test Accuracy: 67.16%
#
# --- Round 222 ---
# Global Test Accuracy: 67.90%
#
# --- Round 223 ---
# Global Test Accuracy: 67.10%
#
# --- Round 224 ---
# Global Test Accuracy: 66.10%
#
# --- Round 225 ---
# Global Test Accuracy: 65.63%
#
# --- Round 226 ---
# Global Test Accuracy: 67.65%
#
# --- Round 227 ---
# Global Test Accuracy: 67.32%
#
# --- Round 228 ---
# Global Test Accuracy: 67.98%
#
# --- Round 229 ---
# Global Test Accuracy: 67.07%
#
# --- Round 230 ---
# Global Test Accuracy: 66.63%
#
# --- Round 231 ---
# Global Test Accuracy: 66.62%
#
# --- Round 232 ---
# Global Test Accuracy: 66.92%
#
# --- Round 233 ---
# Global Test Accuracy: 67.98%
#
# --- Round 234 ---
# Global Test Accuracy: 69.42%
#
# --- Round 235 ---
# Global Test Accuracy: 69.97%
#
# --- Round 236 ---
# Global Test Accuracy: 70.48%
#
# --- Round 237 ---
# Global Test Accuracy: 70.65%
#
# --- Round 238 ---
# Global Test Accuracy: 72.11%
#
# --- Round 239 ---
# Global Test Accuracy: 71.75%
#
# --- Round 240 ---
# Global Test Accuracy: 73.90%
#
# --- Round 241 ---
# Global Test Accuracy: 72.69%
#
# --- Round 242 ---
# Global Test Accuracy: 74.15%
#
# --- Round 243 ---
# Global Test Accuracy: 74.91%
#
# --- Round 244 ---
# Global Test Accuracy: 74.51%
#
# --- Round 245 ---
# Global Test Accuracy: 75.79%
#
# --- Round 246 ---
# Global Test Accuracy: 74.51%
#
# --- Round 247 ---
# Global Test Accuracy: 72.68%
#
# --- Round 248 ---
# Global Test Accuracy: 71.35%
#
# --- Round 249 ---
# Global Test Accuracy: 74.09%
#
# --- Round 250 ---
# Global Test Accuracy: 74.03%
#
# --- Round 251 ---
# Global Test Accuracy: 73.94%
#
# --- Round 252 ---
# Global Test Accuracy: 74.99%
#
# --- Round 253 ---
# Global Test Accuracy: 74.52%
#
# --- Round 254 ---
# Global Test Accuracy: 73.34%
#
# --- Round 255 ---
# Global Test Accuracy: 72.56%
#
# --- Round 256 ---
# Global Test Accuracy: 73.00%
#
# --- Round 257 ---
# Global Test Accuracy: 73.91%
#
# --- Round 258 ---
# Global Test Accuracy: 73.47%
#
# --- Round 259 ---
# Global Test Accuracy: 74.93%
#
# --- Round 260 ---
# Global Test Accuracy: 76.10%
#
# --- Round 261 ---
# Global Test Accuracy: 75.59%
#
# --- Round 262 ---
# Global Test Accuracy: 75.93%
#
# --- Round 263 ---
# Global Test Accuracy: 75.12%
#
# --- Round 264 ---
# Global Test Accuracy: 76.31%
#
# --- Round 265 ---
# Global Test Accuracy: 75.18%
#
# --- Round 266 ---
# Global Test Accuracy: 77.15%
#
# --- Round 267 ---
# Global Test Accuracy: 77.95%
#
# --- Round 268 ---
# Global Test Accuracy: 78.40%
#
# --- Round 269 ---
# Global Test Accuracy: 79.32%
#
# --- Round 270 ---
# Global Test Accuracy: 79.31%
#
# --- Round 271 ---
# Global Test Accuracy: 78.79%
#
# --- Round 272 ---
# Global Test Accuracy: 79.51%
#
# --- Round 273 ---
# Global Test Accuracy: 78.86%
#
# --- Round 274 ---
# Global Test Accuracy: 79.66%
#
# --- Round 275 ---
# Global Test Accuracy: 80.20%
#
# --- Round 276 ---
# Global Test Accuracy: 80.45%
#
# --- Round 277 ---
# Global Test Accuracy: 80.11%
#
# --- Round 278 ---
# Global Test Accuracy: 80.30%
#
# --- Round 279 ---
# Global Test Accuracy: 80.68%
#
# --- Round 280 ---
# Global Test Accuracy: 79.34%
#
# --- Round 281 ---
# Global Test Accuracy: 79.83%
#
# --- Round 282 ---
# Global Test Accuracy: 79.66%
#
# --- Round 283 ---
# Global Test Accuracy: 78.08%
#
# --- Round 284 ---
# Global Test Accuracy: 80.28%
#
# --- Round 285 ---
# Global Test Accuracy: 79.94%
#
# --- Round 286 ---
# Global Test Accuracy: 81.41%
#
# --- Round 287 ---
# Global Test Accuracy: 81.16%
#
# --- Round 288 ---
# Global Test Accuracy: 81.88%
#
# --- Round 289 ---
# Global Test Accuracy: 82.25%
#
# --- Round 290 ---
# Global Test Accuracy: 82.53%
#
# --- Round 291 ---
# Global Test Accuracy: 82.30%
#
# --- Round 292 ---
# Global Test Accuracy: 81.84%
#
# --- Round 293 ---
# Global Test Accuracy: 81.20%
#
# --- Round 294 ---
# Global Test Accuracy: 81.33%
#
# --- Round 295 ---
# Global Test Accuracy: 82.24%
#
# --- Round 296 ---
# Global Test Accuracy: 80.72%
#
# --- Round 297 ---
# Global Test Accuracy: 81.26%
#
# --- Round 298 ---
# Global Test Accuracy: 80.28%
#
# --- Round 299 ---
# Global Test Accuracy: 80.44%
#
# --- Round 300 ---
# Global Test Accuracy: 81.70%
#
# --- Round 301 ---
# Global Test Accuracy: 81.62%
#
# --- Round 302 ---
# Global Test Accuracy: 82.20%
#
# --- Round 303 ---
# Global Test Accuracy: 82.68%
#
# --- Round 304 ---
# Global Test Accuracy: 82.69%
#
# --- Round 305 ---
# Global Test Accuracy: 82.16%
#
# --- Round 306 ---
# Global Test Accuracy: 82.06%
#
# --- Round 307 ---
# Global Test Accuracy: 83.17%
#
# --- Round 308 ---
# Global Test Accuracy: 83.22%
#
# --- Round 309 ---
# Global Test Accuracy: 82.72%
#
# --- Round 310 ---
# Global Test Accuracy: 82.92%
#
# --- Round 311 ---
# Global Test Accuracy: 82.39%
#
# --- Round 312 ---
# Global Test Accuracy: 83.10%
#
# --- Round 313 ---
# Global Test Accuracy: 83.39%
#
# --- Round 314 ---
# Global Test Accuracy: 83.36%
#
# --- Round 315 ---
# Global Test Accuracy: 83.57%
#
# --- Round 316 ---
# Global Test Accuracy: 83.77%
#
# --- Round 317 ---
# Global Test Accuracy: 84.03%
#
# --- Round 318 ---
# Global Test Accuracy: 84.02%
#
# --- Round 319 ---
# Global Test Accuracy: 82.64%
#
# --- Round 320 ---
# Global Test Accuracy: 83.37%
#
# --- Round 321 ---
# Global Test Accuracy: 83.54%
#
# --- Round 322 ---
# Global Test Accuracy: 83.47%
#
# --- Round 323 ---
# Global Test Accuracy: 84.10%
#
# --- Round 324 ---
# Global Test Accuracy: 84.17%
#
# --- Round 325 ---
# Global Test Accuracy: 84.22%
#
# --- Round 326 ---
# Global Test Accuracy: 84.00%
#
# --- Round 327 ---
# Global Test Accuracy: 84.15%
#
# --- Round 328 ---
# Global Test Accuracy: 83.77%
#
# --- Round 329 ---
# Global Test Accuracy: 83.76%
#
# --- Round 330 ---
# Global Test Accuracy: 83.49%
#
# --- Round 331 ---
# Global Test Accuracy: 82.40%
#
# --- Round 332 ---
# Global Test Accuracy: 83.18%
#
# --- Round 333 ---
# Global Test Accuracy: 84.92%
#
# --- Round 334 ---
# Global Test Accuracy: 84.59%
#
# --- Round 335 ---
# Global Test Accuracy: 84.34%
#
# --- Round 336 ---
# Global Test Accuracy: 85.07%
#
# --- Round 337 ---
# Global Test Accuracy: 84.43%
#
# --- Round 338 ---
# Global Test Accuracy: 84.72%
#
# --- Round 339 ---
# Global Test Accuracy: 84.74%
#
# --- Round 340 ---
# Global Test Accuracy: 84.95%
#
# --- Round 341 ---
# Global Test Accuracy: 85.39%
#
# --- Round 342 ---
# Global Test Accuracy: 85.12%
#
# --- Round 343 ---
# Global Test Accuracy: 85.72%
#
# --- Round 344 ---
# Global Test Accuracy: 84.27%
#
# --- Round 345 ---
# Global Test Accuracy: 85.16%
#
# --- Round 346 ---
# Global Test Accuracy: 85.55%
#
# --- Round 347 ---
# Global Test Accuracy: 85.31%
#
# --- Round 348 ---
# Global Test Accuracy: 85.06%
#
# --- Round 349 ---
# Global Test Accuracy: 85.73%
#
# --- Round 350 ---
# Global Test Accuracy: 85.83%
#
# --- Round 351 ---
# Global Test Accuracy: 85.81%
#
# --- Round 352 ---
# Global Test Accuracy: 85.34%
#
# --- Round 353 ---
# Global Test Accuracy: 85.43%
#
# --- Round 354 ---
# Global Test Accuracy: 85.54%
#
# --- Round 355 ---
# Global Test Accuracy: 85.54%
#
# --- Round 356 ---
# Global Test Accuracy: 85.40%
#
# --- Round 357 ---
# Global Test Accuracy: 85.48%
#
# --- Round 358 ---
# Global Test Accuracy: 85.41%
#
# --- Round 359 ---
# Global Test Accuracy: 85.63%
#
# --- Round 360 ---
# Global Test Accuracy: 86.05%
#
# --- Round 361 ---
# Global Test Accuracy: 85.47%
#
# --- Round 362 ---
# Global Test Accuracy: 85.31%
#
# --- Round 363 ---
# Global Test Accuracy: 85.88%
#
# --- Round 364 ---
# Global Test Accuracy: 85.64%
#
# --- Round 365 ---
# Global Test Accuracy: 86.10%
#
# --- Round 366 ---
# Global Test Accuracy: 86.56%
#
# --- Round 367 ---
# Global Test Accuracy: 86.42%
#
# --- Round 368 ---
# Global Test Accuracy: 86.50%
#
# --- Round 369 ---
# Global Test Accuracy: 86.10%
#
# --- Round 370 ---
# Global Test Accuracy: 85.14%
#
# --- Round 371 ---
# Global Test Accuracy: 86.39%
#
# --- Round 372 ---
# Global Test Accuracy: 85.98%
#
# --- Round 373 ---
# Global Test Accuracy: 86.20%
#
# --- Round 374 ---
# Global Test Accuracy: 86.45%
#
# --- Round 375 ---
# Global Test Accuracy: 86.47%
#
# --- Round 376 ---
# Global Test Accuracy: 86.45%
#
# --- Round 377 ---
# Global Test Accuracy: 85.87%
#
# --- Round 378 ---
# Global Test Accuracy: 86.37%
#
# --- Round 379 ---
# Global Test Accuracy: 86.53%
#
# --- Round 380 ---
# Global Test Accuracy: 85.90%
#
# --- Round 381 ---
# Global Test Accuracy: 86.28%
#
# --- Round 382 ---
# Global Test Accuracy: 86.02%
#
# --- Round 383 ---
# Global Test Accuracy: 85.65%
#
# --- Round 384 ---
# Global Test Accuracy: 86.56%
#
# --- Round 385 ---
# Global Test Accuracy: 86.23%
#
# --- Round 386 ---
# Global Test Accuracy: 86.15%
#
# --- Round 387 ---
# Global Test Accuracy: 86.52%
#
# --- Round 388 ---
# Global Test Accuracy: 86.89%
#
# --- Round 389 ---
# Global Test Accuracy: 86.25%
#
# --- Round 390 ---
# Global Test Accuracy: 86.35%
#
# --- Round 391 ---
# Global Test Accuracy: 86.71%
#
# --- Round 392 ---
# Global Test Accuracy: 86.99%
#
# --- Round 393 ---
# Global Test Accuracy: 87.10%
#
# --- Round 394 ---
# Global Test Accuracy: 87.00%
#
# --- Round 395 ---
# Global Test Accuracy: 86.71%
#
# --- Round 396 ---
# Global Test Accuracy: 87.00%
#
# --- Round 397 ---
# Global Test Accuracy: 86.48%
#
# --- Round 398 ---
# Global Test Accuracy: 86.81%
#
# --- Round 399 ---
# Global Test Accuracy: 86.75%
#
# --- Round 400 ---
# Global Test Accuracy: 85.55%
#
# --- Round 401 ---
# Global Test Accuracy: 86.88%
#
# --- Round 402 ---
# Global Test Accuracy: 87.25%
#
# --- Round 403 ---
# Global Test Accuracy: 86.58%
#
# --- Round 404 ---
# Global Test Accuracy: 87.11%
#
# --- Round 405 ---
# Global Test Accuracy: 86.80%
#
# --- Round 406 ---
# Global Test Accuracy: 86.66%
#
# --- Round 407 ---
# Global Test Accuracy: 86.87%
#
# --- Round 408 ---
# Global Test Accuracy: 87.56%
#
# --- Round 409 ---
# Global Test Accuracy: 86.95%
#
# --- Round 410 ---
# Global Test Accuracy: 87.09%
#
# --- Round 411 ---
# Global Test Accuracy: 86.83%
#
# --- Round 412 ---
# Global Test Accuracy: 87.25%
#
# --- Round 413 ---
# Global Test Accuracy: 86.48%
#
# --- Round 414 ---
# Global Test Accuracy: 86.44%
#
# --- Round 415 ---
# Global Test Accuracy: 87.49%
#
# --- Round 416 ---
# Global Test Accuracy: 87.13%
#
# --- Round 417 ---
# Global Test Accuracy: 87.48%
#
# --- Round 418 ---
# Global Test Accuracy: 87.23%
#
# --- Round 419 ---
# Global Test Accuracy: 87.53%
#
# --- Round 420 ---
# Global Test Accuracy: 87.11%
#
# --- Round 421 ---
# Global Test Accuracy: 87.53%
#
# --- Round 422 ---
# Global Test Accuracy: 86.81%
#
# --- Round 423 ---
# Global Test Accuracy: 87.73%
#
# --- Round 424 ---
# Global Test Accuracy: 87.55%
#
# --- Round 425 ---
# Global Test Accuracy: 86.36%
#
# --- Round 426 ---
# Global Test Accuracy: 87.37%
#
# --- Round 427 ---
# Global Test Accuracy: 87.60%
#
# --- Round 428 ---
# Global Test Accuracy: 86.86%
#
# --- Round 429 ---
# Global Test Accuracy: 87.58%
#
# --- Round 430 ---
# Global Test Accuracy: 87.30%
#
# --- Round 431 ---
# Global Test Accuracy: 86.47%
#
# --- Round 432 ---
# Global Test Accuracy: 87.68%
#
# --- Round 433 ---
# Global Test Accuracy: 87.44%
#
# --- Round 434 ---
# Global Test Accuracy: 86.60%
#
# --- Round 435 ---
# Global Test Accuracy: 86.88%
#
# --- Round 436 ---
# Global Test Accuracy: 87.59%
#
# --- Round 437 ---
# Global Test Accuracy: 88.04%
#
# --- Round 438 ---
# Global Test Accuracy: 88.01%
#
# --- Round 439 ---
# Global Test Accuracy: 87.90%
#
# --- Round 440 ---
# Global Test Accuracy: 88.06%
#
# --- Round 441 ---
# Global Test Accuracy: 87.33%
#
# --- Round 442 ---
# Global Test Accuracy: 87.55%
#
# --- Round 443 ---
# Global Test Accuracy: 88.02%
#
# --- Round 444 ---
# Global Test Accuracy: 87.44%
#
# --- Round 445 ---
# Global Test Accuracy: 88.21%
#
# --- Round 446 ---
# Global Test Accuracy: 87.93%
#
# --- Round 447 ---
# Global Test Accuracy: 87.85%
#
# --- Round 448 ---
# Global Test Accuracy: 87.54%
#
# --- Round 449 ---
# Global Test Accuracy: 87.40%
#
# --- Round 450 ---
# Global Test Accuracy: 86.42%
#
# --- Round 451 ---
# Global Test Accuracy: 87.49%
#
# --- Round 452 ---
# Global Test Accuracy: 87.21%
#
# --- Round 453 ---
# Global Test Accuracy: 87.52%
#
# --- Round 454 ---
# Global Test Accuracy: 86.52%
#
# --- Round 455 ---
# Global Test Accuracy: 87.53%
#
# --- Round 456 ---
# Global Test Accuracy: 87.34%
#
# --- Round 457 ---
# Global Test Accuracy: 87.27%
#
# --- Round 458 ---
# Global Test Accuracy: 88.00%
#
# --- Round 459 ---
# Global Test Accuracy: 88.00%
#
# --- Round 460 ---
# Global Test Accuracy: 87.97%
#
# --- Round 461 ---
# Global Test Accuracy: 87.92%
#
# --- Round 462 ---
# Global Test Accuracy: 87.41%
#
# --- Round 463 ---
# Global Test Accuracy: 87.14%
#
# --- Round 464 ---
# Global Test Accuracy: 88.21%
#
# --- Round 465 ---
# Global Test Accuracy: 88.42%
#
# --- Round 466 ---
# Global Test Accuracy: 88.02%
#
# --- Round 467 ---
# Global Test Accuracy: 87.62%
#
# --- Round 468 ---
# Global Test Accuracy: 88.10%
#
# --- Round 469 ---
# Global Test Accuracy: 88.26%
#
# --- Round 470 ---
# Global Test Accuracy: 87.27%
#
# --- Round 471 ---
# Global Test Accuracy: 88.45%
#
# --- Round 472 ---
# Global Test Accuracy: 88.06%
#
# --- Round 473 ---
# Global Test Accuracy: 88.40%
#
# --- Round 474 ---
# Global Test Accuracy: 88.05%
#
# --- Round 475 ---
# Global Test Accuracy: 88.35%
#
# --- Round 476 ---
# Global Test Accuracy: 88.36%
#
# --- Round 477 ---
# Global Test Accuracy: 88.71%
#
# --- Round 478 ---
# Global Test Accuracy: 88.34%
#
# --- Round 479 ---
# Global Test Accuracy: 88.19%
#
# --- Round 480 ---
# Global Test Accuracy: 87.45%
#
# --- Round 481 ---
# Global Test Accuracy: 86.76%
#
# --- Round 482 ---
# Global Test Accuracy: 88.34%
#
# --- Round 483 ---
# Global Test Accuracy: 88.62%
#
# --- Round 484 ---
# Global Test Accuracy: 87.75%
#
# --- Round 485 ---
# Global Test Accuracy: 87.64%
#
# --- Round 486 ---
# Global Test Accuracy: 88.41%
#
# --- Round 487 ---
# Global Test Accuracy: 88.04%
#
# --- Round 488 ---
# Global Test Accuracy: 88.41%
#
# --- Round 489 ---
# Global Test Accuracy: 88.18%
#
# --- Round 490 ---
# Global Test Accuracy: 88.47%
#
# --- Round 491 ---
# Global Test Accuracy: 88.22%
#
# --- Round 492 ---
# Global Test Accuracy: 88.42%
#
# --- Round 493 ---
# Global Test Accuracy: 87.86%
#
# --- Round 494 ---
# Global Test Accuracy: 87.83%
#
# --- Round 495 ---
# Global Test Accuracy: 87.79%
#
# --- Round 496 ---
# Global Test Accuracy: 86.97%
#
# --- Round 497 ---
# Global Test Accuracy: 87.97%
#
# --- Round 498 ---
# Global Test Accuracy: 88.49%
#
# --- Round 499 ---
# Global Test Accuracy: 88.74%
#
# --- Round 500 ---
# Global Test Accuracy: 88.72%
